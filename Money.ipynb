# %% [markdown]
# <a href="https://colab.research.google.com/github/thoxinloi/ai/blob/main/Money.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import library
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from tensorflow.keras.optimizers import RMSprop
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt
from keras.utils import np_utils
import tensorflow as tf
import numpy as np
import cv2
import os

# %%
image_generator = ImageDataGenerator(rescale=1./255, validation_split=0.2)    

train_dataset = image_generator.flow_from_directory(batch_size=10,
                                                 directory='/content/drive/MyDrive/Money/',
                                                 shuffle=True,
                                                 target_size=(150, 150), 
                                                 subset="training",
                                                 class_mode='categorical')

validation_dataset = image_generator.flow_from_directory(batch_size=10,
                                                 directory='/content/drive/MyDrive/Money/',
                                                 shuffle=True,
                                                 target_size=(150, 150), 
                                                 subset="validation",
                                                 class_mode='categorical')
# Out:
# Found 176 images belonging to 11 classes.
# Found 44 images belonging to 11 classes.

# %%
# X_train.shape, y_train.shape,X_test.shape,y_test.shape
train_dataset.classes
train_dataset.class_indices
# Out:
# {'1000': 0,
#  '10000': 1,
#  '100000': 2,
#  '200': 3,
#  '2000': 4,
#  '20000': 5,
#  '200000': 6,
#  '500': 7,
#  '5000': 8,
#  '50000': 9,
#  '500000': 10}

# %%
import numpy as np  #
import pandas as pd # xu ly mang
import seaborn as sns # do thi
import matplotlib.pyplot as plt # ve do hoa
from sklearn.preprocessing import StandardScaler  # xu ly du lieu , du lieu k dong deu
from sklearn.model_selection import train_test_split # chia du lieu 
from keras.layers import Dense,Activation,Dropout,BatchNormalization,LSTM #  :batch... : chuan cua ANN
from keras.models import Sequential 
from tensorflow.keras.utils import to_categorical #  de dam bao do hcinh xac cao 
from keras import callbacks #
from sklearn .metrics import  precision_score,recall_score, confusion_matrix, classification_report, accuracy_score,f1_score

# %%
# Tạo mô hinh
from keras.layers import Conv2D, MaxPooling2D
model = Sequential()
model.add(Conv2D(32,(3,3), activation='relu',kernel_initializer='he_uniform',padding='same',input_shape=(150,150,3))) # 32 lần tích chập
model.add(Conv2D(32,(3,3),activation='relu',kernel_initializer='he_uniform',padding='same'))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(64,(3,3), activation='relu',kernel_initializer='he_uniform',padding='same')) # 64 lần tích chập
model.add(Conv2D(64,(3,3),activation='relu',kernel_initializer='he_uniform',padding='same'))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(128,(3,3), activation='relu',kernel_initializer='he_uniform',padding='same')) # 128 lần tích chập
model.add(Conv2D(128,(3,3),activation='relu',kernel_initializer='he_uniform',padding='same'))
model.add(MaxPooling2D(2,2))

# %%
from keras.layers.convolutional import Conv2D, MaxPooling2D

from keras.layers import Dense, Activation, Flatten


model.add(Flatten())
model.add(Dense(128,activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(11,activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 150, 150, 32)      896
#
#  conv2d_1 (Conv2D)           (None, 150, 150, 32)      9248
#
#  max_pooling2d (MaxPooling2D  (None, 75, 75, 32)       0
#  )
#
#  conv2d_2 (Conv2D)           (None, 75, 75, 64)        18496
#
#  conv2d_3 (Conv2D)           (None, 75, 75, 64)        36928
#
#  max_pooling2d_1 (MaxPooling  (None, 37, 37, 64)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 37, 37, 128)       73856
#
#  conv2d_5 (Conv2D)           (None, 37, 37, 128)       147584
#
#  max_pooling2d_2 (MaxPooling  (None, 18, 18, 128)      0
#  2D)
#
#  flatten (Flatten)           (None, 41472)             0
#
#  dense (Dense)               (None, 128)               5308544
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 11)                1419
#
# =================================================================
# Total params: 5,596,971
# Trainable params: 5,596,971
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import SGD
opt = SGD(learning_rate = 0.001, momentum = 0.9)
model .compile(optimizer = opt, loss ='categorical_crossentropy', metrics = ['accuracy'])
history=model.fit(train_dataset,batch_size=32,epochs=200,verbose=1,validation_data=validation_dataset)
# Out:
# 18/18 [==============================] - 2s 132ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 1.2627 - val_accuracy: 0.7500
# Epoch 94/200
# 18/18 [==============================] - 2s 129ms/step - loss: 5.6511e-04 - accuracy: 1.0000 - val_loss: 1.3121 - val_accuracy: 0.7500
# Epoch 95/200
# 18/18 [==============================] - 2s 134ms/step - loss: 5.0577e-04 - accuracy: 1.0000 - val_loss: 1.3102 - val_accuracy: 0.7500
# Epoch 96/200
# 18/18 [==============================] - 3s 190ms/step - loss: 2.5483e-04 - accuracy: 1.0000 - val_loss: 1.3192 - val_accuracy: 0.7500
# Epoch 97/200
# 18/18 [==============================] - 2s 134ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 1.2530 - val_accuracy: 0.7500
# Epoch 98/200
# 18/18 [==============================] - 2s 132ms/step - loss: 0.0063 - accuracy: 0.9943 - val_loss: 1.2431 - val_accuracy: 0.7500
# Epoch 99/200
# 18/18 [==============================] - 2s 131ms/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 1.3281 - val_accuracy: 0.7500
# Epoch 100/200
# 18/18 [==============================] - 3s 164ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 1.2083 - val_accuracy: 0.7500
# Epoch 101/200
# 18/18 [==============================] - 2s 133ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 1.1345 - val_accuracy: 0.7500
# Epoch 102/200
# 18/18 [==============================] - 2s 130ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 1.1200 - val_accuracy: 0.7500
# Epoch 103/200
# 18/18 [==============================] - 2s 133ms/step - loss: 3.1397e-04 - accuracy: 1.0000 - val_loss: 1.1334 - val_accuracy: 0.7500
# Epoch 104/200
# 18/18 [==============================] - 3s 151ms/step - loss: 3.5272e-04 - accuracy: 1.0000 - val_loss: 1.1424 - val_accuracy: 0.7500
# Epoch 105/200
# 18/18 [==============================] - 3s 190ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 1.1679 - val_accuracy: 0.7500
# Epoch 106/200
# 18/18 [==============================] - 2s 128ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 1.1762 - val_accuracy: 0.7500
# Epoch 107/200
# 18/18 [==============================] - 2s 126ms/step - loss: 1.6798e-04 - accuracy: 1.0000 - val_loss: 1.1835 - val_accuracy: 0.7500
# Epoch 108/200
# 18/18 [==============================] - 2s 136ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 1.2762 - val_accuracy: 0.7500
# Epoch 109/200
# 18/18 [==============================] - 2s 134ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 1.2275 - val_accuracy: 0.7727
# Epoch 110/200
# 18/18 [==============================] - 3s 196ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 1.2406 - val_accuracy: 0.7727
# Epoch 111/200
# 18/18 [==============================] - 2s 130ms/step - loss: 1.3077e-04 - accuracy: 1.0000 - val_loss: 1.2317 - val_accuracy: 0.7500
# Epoch 112/200
# 18/18 [==============================] - 2s 123ms/step - loss: 1.7183e-04 - accuracy: 1.0000 - val_loss: 1.2325 - val_accuracy: 0.7500
# Epoch 113/200
# 18/18 [==============================] - 2s 129ms/step - loss: 2.8144e-04 - accuracy: 1.0000 - val_loss: 1.2348 - val_accuracy: 0.7500
# Epoch 114/200
# 18/18 [==============================] - 3s 165ms/step - loss: 7.5633e-05 - accuracy: 1.0000 - val_loss: 1.2366 - val_accuracy: 0.7500
# Epoch 115/200
# 18/18 [==============================] - 3s 167ms/step - loss: 4.6494e-04 - accuracy: 1.0000 - val_loss: 1.2350 - val_accuracy: 0.7500
# Epoch 116/200
# 18/18 [==============================] - 2s 134ms/step - loss: 4.9756e-04 - accuracy: 1.0000 - val_loss: 1.2281 - val_accuracy: 0.7500
# Epoch 117/200
# 18/18 [==============================] - 2s 130ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 1.1598 - val_accuracy: 0.7500
# Epoch 118/200
# 18/18 [==============================] - 2s 121ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 1.1969 - val_accuracy: 0.7500
# Epoch 119/200
# 18/18 [==============================] - 3s 145ms/step - loss: 9.8786e-05 - accuracy: 1.0000 - val_loss: 1.2164 - val_accuracy: 0.7500
# Epoch 120/200
# 18/18 [==============================] - 3s 188ms/step - loss: 9.3086e-04 - accuracy: 1.0000 - val_loss: 1.2160 - val_accuracy: 0.7500
# Epoch 121/200
# 18/18 [==============================] - 2s 131ms/step - loss: 5.9561e-04 - accuracy: 1.0000 - val_loss: 1.2172 - val_accuracy: 0.7500
# Epoch 122/200
# 18/18 [==============================] - 2s 124ms/step - loss: 2.9903e-04 - accuracy: 1.0000 - val_loss: 1.2048 - val_accuracy: 0.7500
# Epoch 123/200
# 18/18 [==============================] - 2s 128ms/step - loss: 3.2080e-04 - accuracy: 1.0000 - val_loss: 1.1945 - val_accuracy: 0.7500
# Epoch 124/200
# 18/18 [==============================] - 2s 133ms/step - loss: 4.3639e-04 - accuracy: 1.0000 - val_loss: 1.1991 - val_accuracy: 0.7500
# Epoch 125/200
# 18/18 [==============================] - 3s 192ms/step - loss: 4.8238e-04 - accuracy: 1.0000 - val_loss: 1.1769 - val_accuracy: 0.7727
# Epoch 126/200
# 18/18 [==============================] - 2s 129ms/step - loss: 1.4034e-04 - accuracy: 1.0000 - val_loss: 1.1615 - val_accuracy: 0.7727
# Epoch 127/200
# 18/18 [==============================] - 2s 134ms/step - loss: 4.6999e-04 - accuracy: 1.0000 - val_loss: 1.1458 - val_accuracy: 0.7727
# Epoch 128/200
# 18/18 [==============================] - 2s 132ms/step - loss: 6.5584e-04 - accuracy: 1.0000 - val_loss: 1.1473 - val_accuracy: 0.7727
# Epoch 129/200
# 18/18 [==============================] - 3s 152ms/step - loss: 6.5748e-04 - accuracy: 1.0000 - val_loss: 1.1632 - val_accuracy: 0.7727
# Epoch 130/200
# 18/18 [==============================] - 3s 190ms/step - loss: 2.2452e-04 - accuracy: 1.0000 - val_loss: 1.1698 - val_accuracy: 0.7727
# Epoch 131/200
# 18/18 [==============================] - 2s 138ms/step - loss: 2.3026e-04 - accuracy: 1.0000 - val_loss: 1.1663 - val_accuracy: 0.7727
# Epoch 132/200
# 18/18 [==============================] - 2s 133ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 1.2255 - val_accuracy: 0.7727
# Epoch 133/200
# 18/18 [==============================] - 2s 132ms/step - loss: 2.5952e-04 - accuracy: 1.0000 - val_loss: 1.2497 - val_accuracy: 0.7727
# Epoch 134/200
# 18/18 [==============================] - 3s 184ms/step - loss: 1.7012e-04 - accuracy: 1.0000 - val_loss: 1.2538 - val_accuracy: 0.7727
# Epoch 135/200
# 18/18 [==============================] - 3s 165ms/step - loss: 3.8758e-04 - accuracy: 1.0000 - val_loss: 1.2435 - val_accuracy: 0.7727
# Epoch 136/200
# 18/18 [==============================] - 2s 137ms/step - loss: 6.4842e-05 - accuracy: 1.0000 - val_loss: 1.2373 - val_accuracy: 0.7727
# Epoch 137/200
# 18/18 [==============================] - 2s 136ms/step - loss: 5.8479e-04 - accuracy: 1.0000 - val_loss: 1.2423 - val_accuracy: 0.7727
# Epoch 138/200
# 18/18 [==============================] - 2s 135ms/step - loss: 8.5492e-05 - accuracy: 1.0000 - val_loss: 1.2485 - val_accuracy: 0.7727
# Epoch 139/200
# 18/18 [==============================] - 3s 159ms/step - loss: 6.0890e-04 - accuracy: 1.0000 - val_loss: 1.2475 - val_accuracy: 0.7727
# Epoch 140/200
# 18/18 [==============================] - 3s 179ms/step - loss: 3.0998e-04 - accuracy: 1.0000 - val_loss: 1.2246 - val_accuracy: 0.7727
# Epoch 141/200
# 18/18 [==============================] - 2s 137ms/step - loss: 4.6065e-04 - accuracy: 1.0000 - val_loss: 1.2298 - val_accuracy: 0.7727
# Epoch 142/200
# 18/18 [==============================] - 2s 135ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 1.2738 - val_accuracy: 0.7727
# Epoch 143/200
# 18/18 [==============================] - 2s 136ms/step - loss: 1.5821e-04 - accuracy: 1.0000 - val_loss: 1.2654 - val_accuracy: 0.7727
# Epoch 144/200
# 18/18 [==============================] - 3s 193ms/step - loss: 5.5313e-05 - accuracy: 1.0000 - val_loss: 1.2607 - val_accuracy: 0.7727
# Epoch 145/200
# 18/18 [==============================] - 2s 133ms/step - loss: 9.1057e-04 - accuracy: 1.0000 - val_loss: 1.2603 - val_accuracy: 0.7727
# Epoch 146/200
# 18/18 [==============================] - 2s 132ms/step - loss: 4.1335e-04 - accuracy: 1.0000 - val_loss: 1.2688 - val_accuracy: 0.7727
# Epoch 147/200
# 18/18 [==============================] - 2s 131ms/step - loss: 5.9215e-05 - accuracy: 1.0000 - val_loss: 1.2453 - val_accuracy: 0.7727
# Epoch 148/200
# 18/18 [==============================] - 3s 164ms/step - loss: 5.7772e-04 - accuracy: 1.0000 - val_loss: 1.2514 - val_accuracy: 0.7727
# Epoch 149/200
# 18/18 [==============================] - 3s 168ms/step - loss: 6.1171e-05 - accuracy: 1.0000 - val_loss: 1.2655 - val_accuracy: 0.7727
# Epoch 150/200
# 18/18 [==============================] - 2s 135ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 1.2290 - val_accuracy: 0.7727
# Epoch 151/200
# 18/18 [==============================] - 2s 131ms/step - loss: 8.9033e-05 - accuracy: 1.0000 - val_loss: 1.2265 - val_accuracy: 0.7727
# Epoch 152/200
# 18/18 [==============================] - 2s 135ms/step - loss: 4.0373e-04 - accuracy: 1.0000 - val_loss: 1.2231 - val_accuracy: 0.7727
# Epoch 153/200
# 18/18 [==============================] - 3s 148ms/step - loss: 0.0068 - accuracy: 0.9943 - val_loss: 1.2054 - val_accuracy: 0.7727
# Epoch 154/200
# 18/18 [==============================] - 3s 189ms/step - loss: 0.0046 - accuracy: 1.0000 - val_loss: 1.9697 - val_accuracy: 0.6591
# Epoch 155/200
# 18/18 [==============================] - 2s 130ms/step - loss: 0.0307 - accuracy: 0.9943 - val_loss: 1.1758 - val_accuracy: 0.7727
# Epoch 156/200
# 18/18 [==============================] - 2s 132ms/step - loss: 0.0085 - accuracy: 1.0000 - val_loss: 1.1621 - val_accuracy: 0.7727
# Epoch 157/200
# 18/18 [==============================] - 2s 128ms/step - loss: 0.0091 - accuracy: 0.9943 - val_loss: 1.1413 - val_accuracy: 0.7727
# Epoch 158/200
# 18/18 [==============================] - 3s 164ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 1.2370 - val_accuracy: 0.7500
# Epoch 159/200
# 18/18 [==============================] - 2s 133ms/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 1.2802 - val_accuracy: 0.7273
# Epoch 160/200
# 18/18 [==============================] - 2s 132ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 1.1897 - val_accuracy: 0.7500
# Epoch 161/200
# 18/18 [==============================] - 2s 125ms/step - loss: 0.0075 - accuracy: 0.9943 - val_loss: 1.3872 - val_accuracy: 0.7273
# Epoch 162/200
# 18/18 [==============================] - 3s 146ms/step - loss: 7.1120e-04 - accuracy: 1.0000 - val_loss: 1.4261 - val_accuracy: 0.7273
# Epoch 163/200
# 18/18 [==============================] - 2s 134ms/step - loss: 8.0274e-04 - accuracy: 1.0000 - val_loss: 1.3852 - val_accuracy: 0.7273
# Epoch 164/200
# 18/18 [==============================] - 2s 129ms/step - loss: 4.4441e-04 - accuracy: 1.0000 - val_loss: 1.3562 - val_accuracy: 0.7273
# Epoch 165/200
# 18/18 [==============================] - 2s 131ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 1.2603 - val_accuracy: 0.7727
# Epoch 166/200
# 18/18 [==============================] - 3s 142ms/step - loss: 6.8942e-04 - accuracy: 1.0000 - val_loss: 1.2435 - val_accuracy: 0.7727
# Epoch 167/200
# 18/18 [==============================] - 3s 193ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 1.2290 - val_accuracy: 0.7727
# Epoch 168/200
# 18/18 [==============================] - 2s 132ms/step - loss: 0.0267 - accuracy: 0.9886 - val_loss: 1.0792 - val_accuracy: 0.7727
# Epoch 169/200
# 18/18 [==============================] - 2s 132ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.9422 - val_accuracy: 0.7727
# Epoch 170/200
# 18/18 [==============================] - 2s 133ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.9012 - val_accuracy: 0.8182
# Epoch 171/200
# 18/18 [==============================] - 3s 159ms/step - loss: 7.7177e-04 - accuracy: 1.0000 - val_loss: 0.8921 - val_accuracy: 0.7955
# Epoch 172/200
# 18/18 [==============================] - 3s 160ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.9303 - val_accuracy: 0.7955
# Epoch 173/200
# 18/18 [==============================] - 2s 132ms/step - loss: 5.0559e-04 - accuracy: 1.0000 - val_loss: 0.9637 - val_accuracy: 0.7955
# Epoch 174/200
# 18/18 [==============================] - 2s 134ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.9595 - val_accuracy: 0.7955
# Epoch 175/200
# 18/18 [==============================] - 2s 131ms/step - loss: 7.1248e-04 - accuracy: 1.0000 - val_loss: 1.1441 - val_accuracy: 0.7500
# Epoch 176/200
# 18/18 [==============================] - 3s 141ms/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 1.2546 - val_accuracy: 0.7500
# Epoch 177/200
# 18/18 [==============================] - 3s 198ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 1.2645 - val_accuracy: 0.7500
# Epoch 178/200
# 18/18 [==============================] - 2s 134ms/step - loss: 4.5236e-05 - accuracy: 1.0000 - val_loss: 1.2107 - val_accuracy: 0.7500
# Epoch 179/200
# 18/18 [==============================] - 2s 127ms/step - loss: 1.6892e-04 - accuracy: 1.0000 - val_loss: 1.2006 - val_accuracy: 0.7500
# Epoch 180/200
# 18/18 [==============================] - 2s 128ms/step - loss: 5.2706e-04 - accuracy: 1.0000 - val_loss: 1.1920 - val_accuracy: 0.7500
# Epoch 181/200
# 18/18 [==============================] - 2s 131ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 1.1669 - val_accuracy: 0.7500
# Epoch 182/200
# 18/18 [==============================] - 3s 184ms/step - loss: 5.2822e-04 - accuracy: 1.0000 - val_loss: 1.1615 - val_accuracy: 0.7500
# Epoch 183/200
# 18/18 [==============================] - 2s 131ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 1.2016 - val_accuracy: 0.7500
# Epoch 184/200
# 18/18 [==============================] - 2s 136ms/step - loss: 0.0049 - accuracy: 1.0000 - val_loss: 1.3816 - val_accuracy: 0.7500
# Epoch 185/200
# 18/18 [==============================] - 2s 129ms/step - loss: 8.0304e-04 - accuracy: 1.0000 - val_loss: 1.3854 - val_accuracy: 0.7500
# Epoch 186/200
# 18/18 [==============================] - 3s 150ms/step - loss: 1.9994e-04 - accuracy: 1.0000 - val_loss: 1.3793 - val_accuracy: 0.7727
# Epoch 187/200
# 18/18 [==============================] - 3s 178ms/step - loss: 7.0868e-04 - accuracy: 1.0000 - val_loss: 1.3031 - val_accuracy: 0.7955
# Epoch 188/200
# 18/18 [==============================] - 2s 131ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 1.2404 - val_accuracy: 0.7955
# Epoch 189/200
# 18/18 [==============================] - 2s 127ms/step - loss: 8.0653e-04 - accuracy: 1.0000 - val_loss: 1.1863 - val_accuracy: 0.7955
# Epoch 190/200
# 18/18 [==============================] - 2s 132ms/step - loss: 1.5581e-04 - accuracy: 1.0000 - val_loss: 1.1776 - val_accuracy: 0.7955
# Epoch 191/200
# 18/18 [==============================] - 2s 131ms/step - loss: 7.2221e-04 - accuracy: 1.0000 - val_loss: 1.1753 - val_accuracy: 0.7727
# Epoch 192/200
# 18/18 [==============================] - 3s 184ms/step - loss: 8.3403e-05 - accuracy: 1.0000 - val_loss: 1.1779 - val_accuracy: 0.7727
# Epoch 193/200
# 18/18 [==============================] - 2s 127ms/step - loss: 1.8414e-04 - accuracy: 1.0000 - val_loss: 1.1831 - val_accuracy: 0.7727
# Epoch 194/200
# 18/18 [==============================] - 2s 133ms/step - loss: 3.2637e-04 - accuracy: 1.0000 - val_loss: 1.2040 - val_accuracy: 0.7727
# Epoch 195/200
# 18/18 [==============================] - 3s 146ms/step - loss: 4.4294e-05 - accuracy: 1.0000 - val_loss: 1.2093 - val_accuracy: 0.7727
# Epoch 196/200
# 18/18 [==============================] - 3s 168ms/step - loss: 1.4551e-04 - accuracy: 1.0000 - val_loss: 1.2144 - val_accuracy: 0.7727
# Epoch 197/200
# 18/18 [==============================] - 3s 171ms/step - loss: 5.3854e-04 - accuracy: 1.0000 - val_loss: 1.2165 - val_accuracy: 0.7727
# Epoch 198/200
# 18/18 [==============================] - 2s 133ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 1.1966 - val_accuracy: 0.7727
# Epoch 199/200
# 18/18 [==============================] - 2s 133ms/step - loss: 5.8346e-05 - accuracy: 1.0000 - val_loss: 1.1934 - val_accuracy: 0.7727
# Epoch 200/200
# 18/18 [==============================] - 2s 131ms/step - loss: 8.3054e-05 - accuracy: 1.0000 - val_loss: 1.1952 - val_accuracy: 0.7727

# %%
model.save('Money.h5')

# %%
# vẽ lại quá trình học
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epochs')
plt.legend(['train','Validation'])
plt.show()

# %%
#in sai so va do chinh xac
score = model.evaluate(validation_dataset,verbose=0)
print('Sai số : ',score[0])
print('Độ chính xác ',score[1])
# Out:
# Sai số :  1.1951731443405151
# Độ chính xác  0.7727272510528564

# %%
from tensorflow.keras.utils import load_img, img_to_array
import numpy as np
filename = '/content/drive/MyDrive/2xi.jpg'

img = load_img(filename,target_size=(150,150))
img_show = plt.imshow(img)
plt.show()
img = img_to_array(img)
img = img.reshape(1,150,150,3)
img = img.astype('float32')
img = img/255
kq=np.argmax(model.predict(img),axis=-1)
if(kq==0):
    print("1k")
if(kq==1):
    print("10k")
if(kq==2):
    print("100k")
if(kq==3):
    print("200k")
if(kq==4):
    print("2k")
if(kq==5):
    print("20k")
if(kq==6):
    print("200k")
if(kq==7):
    print("500k")
if(kq==8):
    print("5k")
if(kq==9):
    print("50k")
if(kq==10):
    print("500k")
# Out:
# 1/1 [==============================] - 0s 22ms/step
# 200k
